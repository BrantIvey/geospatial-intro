# %% [markdown]
# #### The following packages will be need to be installed:
# - First install [`geopandas`](https://geopandas.org/index.html)
#     - after install make sure the following [dependencies](https://geopandas.org/install.html) are installed (if not install them separately in order below)
#         - fiona
#         - shapely
#         - pyproj
#         - six
#         - rtree
#         - descartes
# - Next install [`folium`](https://python-visualization.github.io/folium/)

# %%
from shapely.geometry import Point
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import folium
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster

# %% [markdown]
# #### Let's load the Nashville zipcode data and look at the first few rows
# - geopandas reads files with the `read_file()` method
# - The zipcode data was downloaded from https://data.nashville.gov/General-Government/Zip-Codes/u7r5-bpku

# %%
zipcodes = gpd.read_file('../data/zipcodes.geojson')
print(zipcodes.crs)
zipcodes.head( )
# Out:
# epsg:4326
#      zip objectid    po_name      shape_stlength        shape_starea  \
# 0  37115        1    MADISON  178783.02488886821  596553400.57885742
# 1  37216        3  NASHVILLE  75820.997821400058  188884682.28344727
# 2  37204        9  NASHVILLE  93180.292250425613  200664795.51708984
# 3  37027       11  BRENTWOOD   159760.6942933173  174978422.04101562
# 4  37064       18   FRANKLIN  28995.828320601937  46969608.005737305
#
#                                             geometry
# 0  MULTIPOLYGON (((-86.68725 36.31821, -86.68722 ...
# 1  MULTIPOLYGON (((-86.73451 36.23774, -86.73425 ...
# 2  MULTIPOLYGON (((-86.77914 36.13424, -86.77923 ...
# 3  MULTIPOLYGON (((-86.81258 36.06319, -86.81263 ...
# 4  MULTIPOLYGON (((-87.02197 36.01200, -87.02140 ...

# %% [markdown]
# #### Note that _if_ the crs contains init it needs to be [updated](https://geopandas.org/projections.html) so we'll do that

# %%
zipcodes.crs = "EPSG:4326"
print(zipcodes.crs)
# Out:
# EPSG:4326

# %% [markdown]
# #### Now let's look at the difference between calling the first geometry variable.....

# %%
zipcodes.loc[0, 'geometry']

# %% [markdown]
# #### ...and printing it

# %%
print(zipcodes.loc[0, 'geometry'])
# Out:
# MULTIPOLYGON (((-86.68724897141 36.318212121092, -86.687216475338 36.318210560887, -86.687181702435 36.318208780693, -86.68714696276101 36.318206917893, -86.68711218725601 36.318205000347, -86.687077445444 36.318202972151, -86.687042702928 36.318200862685, -86.68703469075101 36.318200362824, -86.687007959928 36.318198697129, -86.68697325063 36.318196422067, -86.686938539918 36.318194065167, -86.68690382778099 36.318191625285, -86.68686914958001 36.318189102792, -86.68683443743301 36.318186498074, -86.6867997571 36.318183810757, -86.686765111412 36.318181040826, -86.686730430357 36.318178188106, -86.686695782299 36.318175225883, -86.68666116771 36.318172208522, -86.686626552408 36.318169108746, -86.686591935688 36.318165926561, -86.68655731872499 36.318162634491, -86.686522735235 36.318159287854, -86.68648815149901 36.318155830759, -86.686453600524 36.318152318529, -86.68641904813001 36.31814872389, -86.68638449549 36.318145018792, -86.686349976324 36.318141259129, -86.68631549014999 36.318137389391, -86.68628096933 36.318133438004, -86.686246516617 36.318129430138, -86.68621202761 36.318125313735, -86.68617760718 36.318121113381, -86.68614315092699 36.318116858854, -86.686108729087 36.318112494817, -86.68607433906 36.318108047609, -86.686039949262 36.318103544879, -86.686005593171 36.318098932643, -86.685971235663 36.318094237998, -86.685939398024 36.318082634251, -86.68590729219601 36.318071498996, -86.685874920782 36.318060887727, -86.68584231535399 36.318050771653, -86.68582538629499 36.318045817313, -86.68580944268599 36.318041152105, -86.68577637041599 36.318032081922, -86.68574309855001 36.318023480412, -86.685709629211 36.318015429399, -86.685675959802 36.31800787396, -86.685642125447 36.318000868832, -86.685608160318 36.317994358884, -86.685573994884 36.317988399449, -86.685539732856 36.317982962468, -86.685505339112 36.317978075611, -86.68547081624 36.317973710821, -86.68543622789301 36.317969869453, -86.68540154318001 36.317966577436, -86.68536676139399 36.317963834774, -86.68533195019501 36.317961615329, -86.685296631768 36.317959617931, -86.685296497355 36.317959611826, -86.68526104442201 36.317957924209, -86.685225561751 36.317956558944, -86.685190048001 36.31795552462, -86.68515453662199 36.317954764393, -86.685118994154 36.317954333964, -86.68508348848999 36.317954234092, -86.685083420601 36.317954233904, -86.685047952189 36.317954434829, -86.68504778177299 36.317954435794, -86.68501241708699 36.317954937711, -86.684976920197 36.317955770571, -86.684941390795 36.317956932663, -86.68490593307 36.317958369605, -86.684870443546 36.317960136348, -86.684835024051 36.317962232888, -86.684801499123 36.317967367212, -86.684767689594 36.317971074161, -86.684733697773 36.317973326831, -86.684699591776 36.317974151733, -86.684665507134 36.317973520632, -86.684631477793 36.317971433333, -86.68459763905 36.317967916542, -86.68456406091801 36.317962970434, -86.684530877033 36.317956593108, -86.684498156464 36.317948839113, -86.684465966872 36.317939682313, -86.684434410539 36.317929174779, -86.684403588837 36.317917345124, -86.684373571297 36.317904219853, -86.68434445928099 36.317889826434, -86.684326674234 36.317879990052, -86.684316287432 36.317874245935, -86.684302824084 36.317865914792, -86.684289191525 36.317857478161, -86.68426324764 36.317839571324, -86.68425610203199 36.317834107592, -86.68423884572699 36.317820888334, -86.684238467028 36.31782059976, -86.684214941205 36.317800597286, -86.684198087132 36.317784659146, -86.684192764759 36.31777962632, -86.684192703379 36.317779560856, -86.684171971159 36.317757713569, -86.684152631595 36.317734995979, -86.684134777648 36.317711445901, -86.68411858438699 36.317687355353, -86.684118479798 36.317687199713, -86.684092188873 36.317669383506, -86.68406566297701 36.317651788949, -86.684038935337 36.31763441471, -86.684012006185 36.317617205848, -86.683984908062 36.317600245732, -86.683957575439 36.317583479794, -86.683930039415 36.31756690614, -86.68390233701599 36.317550554 ...

# %% [markdown]
# #### Plotting a GeoDataFrame is as easy as calling the GeoPandas .plot() function

# %%
zipcodes.plot();

# %% [markdown]
# #### Add information and styling
# - set the `column =` to a column in the GeoDataFrame to color by
# - change the [colormap](https://matplotlib.org/3.1.0/tutorials/colors/colormaps.html)
# - pass in keywords to tweak the legend created by `matplotib`

# %%
#geopandas handles legend styling if you pass a dict of keywords

leg_kwds = {'title': 'Zipcodes', 'loc': 'upper left', 
            'bbox_to_anchor': (1, 1.03), 'ncol': 2}

zipcodes.plot(column = 'zip', figsize=(10, 10),
              edgecolor = 'black',
              legend = True, legend_kwds = leg_kwds, 
              cmap = 'Set2')
plt.show()

# %% [markdown]
# #### Next you will read in the bus stop data
# - downloaded from https://data.nashville.gov/Transportation/Regional-Transportation-Authority-Bus-Stops/p886-fnbd
# - cleaned:
#     - rename columns
#     - drop unwanted columns
#     - parse `lat` and `lng` columns from `location`
# - print the shape
# - take a look at the first 3 rows

# %%
bus_stops = pd.read_csv('../data/busstops_cleaned.csv')
print(bus_stops.shape)
bus_stops.head(3)
# Out:
# (2524, 5)
#                               stop              route  \
# 0  GREEN LN & WHITES CREEK PIKE WB      GOLDEN VALLEY
# 1    _ 9TH AVE S & EDGEHILL AVE SB   8TH AVENUE SOUTH
# 2   DONELSON/DELL STATION OUTBOUND  MURFREESBORO PIKE
#
#                   location        lat        lng
# 0  (36.236249, -86.816722)  36.236249 -86.816722
# 1  (36.142642, -86.780897)  36.142642 -86.780897
# 2  (36.105615, -86.672004)  36.105615 -86.672004

# %% [markdown]
# #### In order to spatially join the bus stops with the zipcodes, you will need to create a GeoDataFrame of bus stops
# - First create a geometry column that is a `Point` datatype

# %%
bus_stops['geometry'] = bus_stops.apply(lambda x: Point((float(x.lng), 
                                                         float(x.lat))), 
                                        axis=1)
bus_stops.head(3)
# Out:
#                               stop              route  \
# 0  GREEN LN & WHITES CREEK PIKE WB      GOLDEN VALLEY
# 1    _ 9TH AVE S & EDGEHILL AVE SB   8TH AVENUE SOUTH
# 2   DONELSON/DELL STATION OUTBOUND  MURFREESBORO PIKE
#
#                   location        lat        lng                      geometry
# 0  (36.236249, -86.816722)  36.236249 -86.816722  POINT (-86.816722 36.236249)
# 1  (36.142642, -86.780897)  36.142642 -86.780897  POINT (-86.780897 36.142642)
# 2  (36.105615, -86.672004)  36.105615 -86.672004  POINT (-86.672004 36.105615)

# %% [markdown]
# #### Now that the bus stops data has a geometry field, you can use it to build a GeoDataFrame
# - you want the CRS for the bus stops to match the CRS in the zipcodes GeoDataFrame

# %%
zipcodes.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
bus_geo = gpd.GeoDataFrame(bus_stops, 
                           crs = zipcodes.crs, 
                           geometry = bus_stops['geometry'])

# %%
type(bus_geo)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %% [markdown]
# #### Now you are ready to combine bus stops and zipcodes with a spatial join
# - first a little clean up for the zipcodes
#     - just keep the zip, po_name, and geometry columns
# - then construct the join
#     - keep in mind that you want to find the bus stops within a zip code polygon
#     - the geometry for the new (combined) GeoDataFrame comes from the left GeoDataFrame

# %%
zipcodes = zipcodes[['zip', 'po_name', 'geometry']]

# %%
stops_by_zip = gpd.sjoin(bus_geo, zipcodes, op = 'within')

# %%
stops_by_zip.head()
# Out:
#                                             stop          route  \
# 0                GREEN LN & WHITES CREEK PIKE WB  GOLDEN VALLEY
# 976   OLD HICKORY BLVD & COBBLESTONE CREEK DR EB  HICKORY HILLS
# 1668                    WHITES CREEK HIGH SCHOOL  HICKORY HILLS
# 2161                     GREEN LN & KNIGHT DR WB  GOLDEN VALLEY
# 2483  OLD HICKORY BLVD & COBBLESTONE CREEK DR WB  HICKORY HILLS
#
#                      location        lat        lng  \
# 0     (36.236249, -86.816722)  36.236249 -86.816722
# 976   (36.278199, -86.789015)  36.278199 -86.789015
# 1668  (36.276203, -86.819009)  36.276203 -86.819009
# 2161  (36.236813, -86.803848)  36.236813 -86.803848
# 2483  (36.278342, -86.788981)  36.278342 -86.788981
#
#                         geometry  index_right    zip       po_name
# 0     POINT (-86.81672 36.23625)           18  37189  WHITES CREEK
# 976   POINT (-86.78902 36.27820)           18  37189  WHITES CREEK
# 1668  POINT (-86.81901 36.27620)           18  37189  WHITES CREEK
# 2161  POINT (-86.80385 36.23681)           18  37189  WHITES CREEK
# 2483  POINT (-86.78898 36.27834)           18  37189  WHITES CREEK

# %% [markdown]
# #### Now that the data is joined spatially you can count the bus stops by zip code  and see how many stops are within each polygon
# - using the `value_counts()` method

# %%
stops_by_zip['zip'].value_counts()
# Out:
# 37207    272
# 37203    237
# 37206    205
# 37211    174
# 37208    165
# 37209    149
# 37210    141
# 37217    121
# 37115    106
# 37013    103
# 37204     90
# 37216     88
# 37214     87
# 37212     86
# 37218     83
# 37215     53
# 37205     52
# 37076     50
# 37219     48
# 37221     45
# 37201     36
# 37138     32
# 37228     27
# 37213     10
# 37027      9
# 37072      7
# 37189      5
# 37240      4
# Name: zip, dtype: int64

# %% [markdown]
# #### Let's take a closer look at the 272 bus stops in the 37207 zip code
# - filter the stops_by_zip data to just get bus stops in 37207
# - filter the zip code geodataframe to just the polygon (row) for 37207

# %%
stops_in_37207 = stops_by_zip.loc[stops_by_zip['zip'] == '37207']
stops_in_37207.shape
# Out:
# (272, 9)

# %%
polygon37207 = zipcodes.loc[zipcodes['zip'] == '37207']
polygon37207.shape
# Out:
# (2, 3)

# %% [markdown]
# #### Now plot these two together
# - first plot the polygons for 37207 and make them light green
# - next plot the points for the bus stops and color them by route

# %%
ax = polygon37207.plot(figsize = (8, 10), color = 'lightgreen')
stops_in_37207.plot( ax = ax, column = 'route');
plt.show();

# %% [markdown]
# #### We're getting there! It would be helpful to have streets, though wouldn't it? We can add a street map with the folium package.

# %% [markdown]
# #### folium maps require a center point for the street map.
# - Make use of a GeoSeries attribute (.centroid) which gives the center of a polygon
# - Since there are two polygons which should we use?

# %%
polygon37207.geometry.centroid
# Out:
# 19    POINT (-86.78726 36.28724)
# 42    POINT (-86.77677 36.23245)
# dtype: geometry

# %%
#find the center of the larger (more southern) polygon and look at it
center = polygon37207.geometry.centroid[42]
print(center)
# Out:
# POINT (-86.77676762469858 36.23245257407244)

# %% [markdown]
# #### Folium requires a location point as an array
# - with *latitude* first
# - but shapely Points have *longitude* first

# %%
# reverse the order when constructing the array for folium location
area_center = [center.y, center.x]

# check the order of area_center, the location for our folium map
print(area_center)
# Out:
# [36.23245257407244, -86.77676762469858]

# %% [markdown]
# #### To create a folium map just call the folium `Map()` constructor
# - `location` is the only argument required by the constructor
#     - Set `area_center` as the `location` of the folium map.
# - `zoom_start` is an optional argument
#     - A setting of 12 should get us nice and close

# %%
#create our map of Nashville and show it
map_37207 = folium.Map(location =  area_center, zoom_start = 12)

# %% [markdown]
# #### Next, let's add our 37207 polygon and bus stop markers.

# %% [markdown]
# #### `itterows()` is a generator that iterates through the rows of a DataFrame and returns a tuple with the row id and row values.
# - Below, we are printing the row values for each row as we iterate through the GeoDataFrame of bus stops in 37207.
# - This idea will be helpful for creating our markers!

# %%
for row_index, row_values in stops_in_37207.iterrows():
    print('index is', row_index)
    print('values are:')
    print(' ')
    print(row_values)
    print('------------------------- ')
# Out:
# index is 9
# values are:
#
# stop                  DOVERSIDE DR & MOORWOOD DR EB
# route                                DICKERSON ROAD
# location                    (36.240342, -86.772854)
# lat                                         36.2403
# lng                                        -86.7729
# geometry       POINT (-86.77285400000001 36.240342)
# index_right                                      42
# zip                                           37207
# po_name                                   NASHVILLE
# Name: 9, dtype: object
# -------------------------
# index is 11
# values are:
#
# stop           ROWAN DR & BUENA VISTA PIKE SB
# route                            WHITES CREEK
# location               (36.21714, -86.819509)
# lat                                   36.2171
# lng                                  -86.8195
# geometry          POINT (-86.819509 36.21714)
# index_right                                42
# zip                                     37207
# po_name                             NASHVILLE
# Name: 11, dtype: object
# -------------------------
# index is 17
# values are:
#
# stop           DICKERSON PIKE & DOUGLAS AVE NB
# route                           DICKERSON ROAD
# location               (36.193984, -86.772378)
# lat                                     36.194
# lng                                   -86.7724
# geometry          POINT (-86.772378 36.193984)
# index_right                                 42
# zip                                      37207
# po_name                              NASHVILLE
# Name: 17, dtype: object
# -------------------------
# index is 39
# values are:
#
# stop                          DICKERSON PIKE & LEMUEL RD SB
# route                                        DICKERSON ROAD
# location                            (36.215223, -86.764056)
# lat                                                 36.2152
# lng                                                -86.7641
# geometry       POINT (-86.76405600000001 36.21522299999999)
# index_right                                              42
# zip                                                   37207
# po_name                                           NASHVILLE
# Name: 39, dtype: object
# -------------------------
# index is 44
# values are:
#
# stop           BAPTIST WORLD CENTER DR & UNNAMED ST SB
# route                                     WHITES CREEK
# location                       (36.195314, -86.780671)
# lat                                            36.1953
# lng                                           -86.7807
# geometry                  POINT (-86.780671 36.195314)
# index_right                                         42
# zip                                              37207
# po_name                                      NASHVILLE
# Name: 44, dtype: object
# -------------------------
# index is 50
# values are:
#
# stop                       JONES AVE & JONES CIR SB
# route                                      McFERRIN
# location                    (36.206463, -86.758067)
# lat                                         36.2065
# lng                                        -86.7581
# geometry       POINT (-86.75806700000001 36.206463)
# index_right                                      42
# zip                                           37207
# po_name                                   NASHVILLE
# Name: 50, dtype: object
# -------------------------
# index is 52
# values are:
#
# stop                    MERIDIAN ST & WILBURN ST SB
# route                                      MERIDIAN
# location                    (36.185733, -86.768284)
# lat                                         36.1857
# lng                                        -86.7683
# geometry       POINT (-86.76828399999999 36.185733)
# index_right                                      42
# zip                                           37207
# po_name                                   NASHVILLE
# Name: 52, dtype: object
# -------------------------
# index is 55
# values are:
#
# stop           MERIDIAN ST & TRUETLAN ST NB
# route                              MERIDIAN
# location            (36.179972, -86.769035)
# lat                                   36.18
# lng                                 -86.769
# geometry       POINT (-86.769035 36.179972)
# index_right                              42
# zip                                   37207
# po_name                           NASHVILLE
# Name: 55, dtype: object
# -------------------------
# index is 77
# values are:
#
# stop           EWING DR & RICHMOND HILL DR EB
# route                          DICKERSON ROAD
# location              (36.230288, -86.773922)
# lat                                   36.2303
# lng                                  -86.7739
# geometry         POINT (-86.773922 36.230288)
# index_right                                42
# zip                                     37207
# po_name                             NASHVILLE
# Name: 77, dtype: object
# -------------------------
# index is 79
# values are:
#
# stop               DICKERSON PIKE & HILLHURST DR SB
# route                                DICKERSON ROAD
# location                    (36.226044, -86.760219)
# lat                                          36.226
# lng                                        -86.7602
# geometry       POINT (-86.76021899999999 36.226044)
# index_right                                      42
# zip                                           37207
# po_name                                   NASHVILLE
# Name: 79, dtype: object
# -------------------------
# index is 83
# values are:
#
# stop           MAPLEWOOD TRC & WALTON LN EB
# route                         HICKORY HILLS
# location            (36.232267, -86.753084)
# lat                                 36.2323
# lng                                -86.7531
# geometry       POINT (-86.753084 36.232267)
# index_right                              42
# zip                                   37207
# po_name                           NASHVILLE
# Name: 83, dtype: object
# -------------------------
# index is 85
# values are:
#
# stop                  MERIDIAN ST & CLEVELAND ST NB
# route                                      MERIDIAN
# location                    (36.186902, -86.768026)
# lat                                         36.1869
# lng                                         -86.768
# geometry       POINT (-86.76802600000001 36.186902)
# index_right                                      42
# zip                                           37207
# po_name                                   NASHVILLE
# Name: 85, dtype: object
# -------------------------
# index is 111
# values are:
#
# stop           MONTGOMERY AVE & BLUE RIDGE AVE NB
# route                                    McFERRIN
# location                  (36.196972, -86.755197)
# lat                                        36.197
# lng                                      -86.7552
# geometry             POINT (-86.755197 36.196972)
# index_right                                    42
# zip                                         37207
# po_name                                 NASHVILLE
# Name: 111, dtype: object
# -------------------------
# index is 114
# values are:
#
# stop            HUNTERS LN & DALMERE DR SB
# route                        HICKORY HILLS
# location            (36.27992, -86.756424)
# lat                                36.2799
# lng                               -86.7564
# geometry       POINT (-86.756424 36.27992)
# index_right                             42
# zip                                  37207
# po_name                          NASHVILLE
# Name: 114, dtype: object
# -------------------------
# index is 116
# values are:
#
# stop           BRICKMONT DR & CHESAPEAKE DR NB
# route                           DICKERSON ROAD
# location               (36.245431, -86.768844)
# lat                                    36.2454
# lng                                   -86.7688
# geometry          POINT (-86.768844 36.245431)
# index_right                                 42
# zip                                      37207
# po_name                              NASHVILLE
# Name: 116, dtype: object
# -------------------------
# index is 129
# values are:
#
# stop           DICKERSON PIKE & EVANSON AVE SB
# route                           DICKERSON ROAD
# location                (36.190474, -86.77296)
# lat                                    36.1905
# lng                                    -86.773
# geometry           POINT (-86.77296 36.190474)
# index_right                                 42
# zip                                      37207
# po_name                              NASHVILLE
# Name: 129, dtype: object
# -------------------------
# index is 131
# values are:
#
# stop           DICKERSON PIKE & MULBERRY DOWNS CIR
# route                                HICKORY HILLS
# location                    (36.25167, -86.757501)
# lat                                        36.2517
# lng                                       -86.7575
# geometry               POINT (-86.757501 36.25167)
# index_right                                     42
# zip                                          37207
# po_name                                  NASHVILLE
# Name: 131, dtype: object
# -------------------------
# index is 134
# values are:
#
# stop           CREEKWOOD DR & OAKVIEW DR SB
# route                        DICKERSON ROAD
# location            (36.234315, -86.767589)
# lat                                 36.2343
# lng                                -86.7676
# geometry       POINT (-86.767589 36.234315)
# index_right                              42
# zip                                   37207
# po_name                           NASHVILLE
# Name: 134, dtype: object
# -------------------------
# index is 157
# values are:
#
# stop           DOVERSIDE DR & MOOREWOOD DR WB
# route                          DICKERSON ROAD
# location              (36.240374, -86.772655)
# lat                                   36.2404
# lng                                  -86.7727
# geometry         POINT (-86.772655 36.240374)
# index_right                                42
# zip                                     37207
# po_name                             NASHVILLE
# Name: 157, dtype: object
# -------------------------
# index is 166
# values are:
#
# stop            EWING DR & RICH ACRES DR WB
# route                        DICKERSON ROAD
# location            (36.230582, -86.765423)
# lat                                 36.2306
# lng                                -86.7654
# geometry       POINT (-86.765423 36.230582)
# index_right                              42
# zip                                   37207
# po_name                           NASHVILLE
# Name: 166, dtype: object
# -------------------------
# index is 167
# values are:
#
# stop           PARKWOOD PARK (VAILVIEW DR & BRICKDALE LN) SB
# route                                         DICKERSON ROAD
# location                             (36.235458, -86.773046)
# lat                                                  36.2355
# lng                                                  -86.773
# geometry                POINT (-86.77304599999999 36.235458)
# index_right                                               42
# zip                                                    37207
# po_name                                            NASHVILLE
# Name: 167, dtype: object
# -------------------------
# index is 192
# values are:
#
# stop                WHITES CREEK PIKE & LUZON ST NB
# route                                  WHITES CREEK
# location                    (36.210243, -86.796294)
# lat                                         36.2102
# lng                                        -86.7963
# geometry       POINT (-86.79629399999999 36.210243)
# index_right                                      42
# zip                                           37207
# po_name                                   NASHVILLE
# Name: 192, dtype: object
# -------------------------
# index is 205
# values are:
#
# stop           BRICK CHURCH PIKE & FERN AVE SB
# route                            GOLDEN VALLEY
# location                (36.19585, -86.776754)
# lat                                    36.1959
# lng                                   -86.7768
# geometry           POINT (-86.776754 36.19585)
# index_right                                 42
# zip                                      37207
# po_name                              NASHVILLE
# Name: 205, dtype: object
# -------------------------
# index is 225
# values are:
#
# stop           BRICK CHURCH PIKE & CHESAPEAKE DR N
# route                               DICKERSON ROAD
# location                     (36.24603, -86.77931)
# lat                                         36.246
# lng                                       -86.7793
# geometry                POINT (-86.77931 36.24603)
# index_right                                     42
# zip                                          37207
# po_name                                  NASHVILLE
# Name: 225, dtype: object
# -------------------------
# index is 232
# values are:
#
# stop                       ROWAN DR & CRAVATH DR EB
# route                                  WHITES CREEK
# location                    (36.220553, -86.811372)
# lat                                         36.2206
# lng                                        -86.8114
# geometry       POINT (-86.81137199999999 36.220553)
# index_right                                      42
# zip                                           37207
# po_name                                   NASHVILLE
# Name: 232, dtype: object
# -------------------------
# index is 240
# values are:
#
# stop           LISCHEY AVE & RICHARDSON AVE SB
# route                                 MERIDIAN
# location               (36.192607, -86.763547)
# lat                                    36.1926
# lng                                   -86.7635
# geometry          POINT (-86.763547 36.192607)
# index_right                                 42
# zip                                      37207
# po_name                              NASHVILLE
# Name: 240, dtype: object
# -------------------------
# index is 254
# values are:
#
# stop           DICKERSON PIKE & NESBITT DR NB
# route                           HICKORY HILLS
# location              (36.276458, -86.751752)
# lat                                   36.2765
# lng                                  -86.7518
# geometry         POINT (-86.751752 36.276458)
# index_right                                42
# zip                                     37207
# po_name                             NASHVILLE
# Name: 254, dtype: object
# -------------------------
# index is 261
# values are:
#
# stop           BAPTIST WORLD CENTER DR & GOOCH ST SB
# route                                   WHITES CREEK
# location                     (36.206038, -86.790873)
# lat                                           36.206
# lng                                         -86.7909
# geometry                POINT (-86.790873 36.206038)
# index_right                                       42
# zip                                            37207
# po_name                                    NASHVILLE
# Name: 261, dtype: object
# -------------------------
# index is 279
# values are:
#
# stop           DICKERSON PIKE & QUEEN AVE NB
# route                         DICKERSON ROAD
# location             (36.208287, -86.767303)
# lat                                  36.2083
# lng                                 -86.7673
# geometry        POINT (-86.767303 36.208287)
# index_right                               42
# zip                                    37207
# po_name                            NASHVILLE
# Name: 279, dtype: object
# -------------------------
# index is 288
# values are:
#
# stop           BRICK CHURCH PIKE & MASONWOOD DR SB
# route                               DICKERSON ROAD
# location                   (36.242816, -86.780512)
# lat                                        36.2428
# lng                                       -86.7805
# geometry              POINT (-86.780512 36.242816)
# index_right                                     42
# zip                                          37207
# po_name                                  NASHVILLE
# Name: 288, dtype: object
# -------------------------
# index is 294
# values are:
#
# stop             CHICKAWSAW AVE & MONTGOMERY AVE EB
# route                                      McFERRIN
# location                     (36.200284, -86.75441)
# lat                                         36.2003
# lng                                        -86.7544
# geometry       POINT (-86.75440999999999 36.200284)
# index_right                                      42
# zip                                           37207
# po_name                                   NASHVILLE
# Name: 294, dtype: object
# -------------------------
# index is 295
# values are:
#
# stop               DICKERSON PIKE & DOVERSIDE DR SB
# route                                DICKERSON ROAD
# location                    (36.244081, -86.756582)
# lat                                         36.2441
# lng                                        -86.7566
# geometry       POINT (-86.75658199999999 36.244081)
# index_right                                      42
# zip                                           37207
# po_name                                   NASHVILLE
# Name: 295, dtype: object
# -------------------------
# index is 302
# values are:
#
# stop                  DICKERSON PIKE & SUNSET CR NB
# route                                DICKERSON ROAD
# location                    (36.223608, -86.760968)
# lat                                         36.2236
# lng                                         -86.761
# geometry       POINT (-86.76096800000001 36.223608)
# index_right                                      42
# zip                                           37207
# po_name                                   NASHVILLE
# Name: 302, dtype: object
# -------------------------
# index is 305
# values are:
#
# stop            JONES AVE & CHEROKEE AVE NB
# route                              McFERRIN
# location            (36.202426, -86.758055)
# lat                                 36.2024
# lng                                -86.7581
# geometry       POINT (-86.758055 36.202426)
# index_right                              42
# zip                                   37207
# po_name                           NASHVILLE
# Name: 305, dtype: object
# -------------------------
# index is 329
# values are:
#
# stop               N DICKERSON PIKE & HANCOCK ST NB
# route                                  WHITES CREEK
# location                    (36.184233, -86.773692)
# lat                                         36.1842
# lng                                        -86.7737
# geometry       POINT (-86.77369200000001 36.184233)
# index_right                                      42
# zip                                           37207
# po_name                                   NASHVILLE
# Name: 329, dtype: object
# -------------------------
# index is 335
# values are:
#
# stop           MONTGOMERY AVE & CROCKETT ST SB
# route                                 McFERRIN
# location               (36.195927, -86.755612)
# lat                                    36.1959
# lng                                   -86.7556
# geometry          POINT (-86.755612 36.195927)
# index_right                                 42
# zip                                      37207
# po_name                              NASHVILLE
# Name: 335, dtype: object
# -------------------------
# index is 339
# values are:
#
# stop           LISCHEY AVE & DOUGLAS AVE NB
# route                              MERIDIAN
# location            (36.194476, -86.763076)
# lat                                 36.1945
# lng                                -86.7631
# geometry       POINT (-86.763076 36.194476)
# index_right                              42
# zip                                   37207
# po_name                           NASHVILLE
# Name: 339, dtype: object
# -------------------------
# index is 341
# values are:
#
# stop           MAPLEWOOD TRC & WALTON LN WB
# route                         HICKORY HILLS
# location            (36.232365, -86.752758)
# lat                                 36.2324
# lng                                -86.7528
# geometry       POINT (-86.752758 36.232365)
# index_right                              42
# zip                                   37207
# po_name                           NASHVILLE
# Name: 341, dtype: object
# -------------------------
# index is 345
# values are:
#
# stop           WHITES CREEK PIKE & LUZON ST SB
# route                             WHITES CREEK
# location               (36.210386, -86.796541)
# lat                                    36.2104
# lng                                   -86.7965
# geometry          POINT (-86.796541 36.210386)
# index_right                                 42
# zip                                      37207
# po_name                              NASHVILLE
# Name: 345, dtype: object
# -------------------------
# index is 346
# values are:
#
# stop           MOOREWOOD DR & BRICKMONT CT SB
# route                          DICKERSON ROAD
# location              (36.246512, -86.773044)
# lat                                   36.2465
# lng                                   -86.773
# geometry         POINT (-86.773044 36.246512)
# index_right                                42
# zip                                     37207
# po_name                             NASHVILLE
# Name: 346, dtype: object
# -------------------------
# index is 351
# values are:
#
# stop               WHITES CREEK PIKE & REVELS DR NB
# route                                  WHITES CREEK
# location                    (36.221018, -86.804779)
# lat                                          36.221
# lng                                        -86.8048
# geometry       POINT (-86.80477900000001 36.221018)
# index_right                                      42
# zip                                           37207
# po_name                                   NASHVILLE
# Name: 351, dtype: object
# -------------------------
# index is 362
# values are:
#
# stop                      MERIDIAN ST & MARIE ST SB
# route                                      MERIDIAN
# location                    (36.196805, -86.767137)
# lat                                         36.1968
# lng                                        -86.7671
# geometry       POINT (-86.76713700000001 36.196805)
# index_right                                      42
# zip                                           37207
# po_name                                   NASHVILLE
# Name: 362, dtype: object
# -------------------------
# index is 379
# values are:
#
# stop                CREEKWOOD DR & PARK CREEK DR WB
# route                                DICKERSON ROAD
# location                    (36.233771, -86.768442)
# lat                                         36.2338
# lng                                        -86.7684
# geometry       POINT (-86.76844200000001 36.233771)
# index_right                                      42
# zip                                           37207
# po_name                                   NASHVILLE
# Name: 379, dtype: object
# -------------------------
# index is 387
# values are:
#
# stop           N 1ST ST & DICKERSON PIKE RAMP SB
# route                               WHITES CREEK
# location                 (36.182314, -86.774085)
# lat                                      36.1823
# lng                                     -86.7741
# geometry            POINT (-86.774085 36.182314)
# index_right                                   42
# zip                                        37207
# po_name                                NASHVILLE
# Name: 387, dtype: object
# -------------------------
# index is 389
# values are:
#
# stop                                901 COWAN ST SB
# route                                 GOLDEN VALLEY
# location                    (36.190252, -86.781232)
# lat                                         36.1903
# lng                                        -86.7812
# geometry       POINT (-86.78123199999999 36.190252)
# index_right                                      42
# zip                                           37207
# po_name                                   NASHVILLE
# Name: 389, dtype: object
# -------------------------
# index is 392
# values are:
#
# stop           BRICKMONT DR & CHESAPEAKE DR EB
# route                           DICKERSON ROAD
# location               (36.245437, -86.769046)
# lat                                    36.2454
# lng                                    -86.769
# geometry          POINT (-86.769046 36.245437)
# index_right                                 42
# zip                                      37207
# po_name                              NASHVILLE
# Name: 392, dtype: object
# -------------------------
# index is 403
# values are:
#
# stop             JONES AVE & NORTON AVE NB
# route                             McFERRIN
# location            (36.20725, -86.757426)
# lat                                36.2073
# lng                               -86.7574
# geometry       POINT (-86.757426 36.20725)
# index_right                             42
# zip                                  37207
# po_name                          NASHVILLE
# Name: 403, dtype: object
# -------------------------
# index is 404
# values are:
#
# stop           DICKERSON PIKE & LORRANE AVE NB
# route                           DICKERSON ROAD
# location               (36.218751, -86.762496)
# lat                                    36.2188
# lng                                   -86.7625
# geometry          POINT (-86.762496 36.218751)
# index_right                                 42
# zip                                      37207
# po_name                              NASHVILLE
# Name: 404, dtype: object
# -------------------------
# index is 424
# values are:
#
# stop            DICKERSON PIKE & RICHARDSON AVE SB
# route                               DICKERSON ROAD
# location                    (36.19201, -86.772771)
# lat                                         36.192
# lng                                       -86.7728
# geometry       POINT (-86.77277099999999 36.19201)
# index_right                                     42
# zip                                          37207
# po_name                                  NASHVILLE
# Name: 424, dtype: object
# -------------------------
# index is 427
# values are:
#
# stop           EWING DR & CLAYMILLE BLVD EB
# route                         GOLDEN VALLEY
# location            (36.231823, -86.801777)
# lat                                 36.2318
# lng                                -86.8018
# geometry       POINT (-86.801777 36.231823)
# index_right                              42
# zip                                   37207
# po_name                           NASHVILLE
# Name: 427, dtype: object
# -------------------------
# index is 435
# values are:
#
# stop           OAKVIEW DR & STARLIGHT DR WB
# route                        DICKERSON ROAD
# location            (36.237796, -86.765826)
# lat                                 36.2378
# lng                                -86.7658
# geometry       POINT (-86.765826 36.237796)
# index_right                              42
# zip                                   37207
# po_name                           NASHVILLE
# Name: 435, dtype: object
# -------------------------
# index is 452
# values are:
#
# stop           DICKERSON PIKE & MULBERRY DOWNS CIR
# route                                HICKORY HILLS
# location                   (36.251286, -86.757254)
# lat                                        36.2513
# lng                                       -86.7573
# geometry              POINT (-86.757254 36.251286)
# index_right                                     42
# zip                                          37207
# po_name                                  NASHVILLE
# Name: 452, dtype: object
# -------------------------
# index is 454
# values are:
#
# stop           RICHMOND HILL DR & CREEKWOOD DR NB
# route                              DICKERSON ROAD
# location                  (36.231274, -86.773473)
# lat                                       36.2313
# lng                                      -86.7735
# geometry             POINT (-86.773473 36.231274)
# index_right                                    42
# zip                                         37207
# po_name                                 NASHVILLE
# Name: 454, dtype: object
# -------------------------
# index is 455
# values are:
#
# stop           GRACE MANOR (OLD HICKORY BLVD & BRICK CHURCH P...
# route                                              HICKORY HILLS
# location                                 (36.279762, -86.780656)
# lat                                                      36.2798
# lng                                                     -86.7807
# geometry                    POINT (-86.78065600000001 36.279762)
# index_right                                                   42
# zip                                                        37207
# po_name                                                NASHVILLE
# Name: 455, dtype: object
# -------------------------
# index is 468
# values are:
#
# stop           BAPTIST WORLD CENTER DR & VASHTI ST WB
# route                                    WHITES CREEK
# location                      (36.194859, -86.779706)
# lat                                           36.1949
# lng                                          -86.7797
# geometry                 POINT (-86.779706 36.194859)
# index_right                                        42
# zip                                             37207
# po_name                                     NASHVILLE
# Name: 468, dtype: object
# -------------------------
# index is 486
# values are:
#
# stop            OLD HICKORY BLVD & GOODMORNING DR W
# route                                 HICKORY HILLS
# location                    (36.277424, -86.769546)
# lat                                         36.2774
# lng                                        -86.7695
# geometry       POINT (-86.76954599999999 36.277424)
# index_right                                      42
# zip                                           37207
# po_name                                   NASHVILLE
# Name: 486, dtype: object
# -------------------------
# index is 495
# values are:
#
# stop           WHITES CREEK PIKE & MALTA DR SB
# route                             WHITES CREEK
# location               (36.216458, -86.802178)
# lat                                    36.2165
# lng                                   -86.8022
# geometry          POINT (-86.802178 36.216458)
# index_right                                 42
# zip                                      37207
# po_name                              NASHVILLE
# Name: 495, dtype: object
# -------------------------
# index is 496
# values are:
#
# stop           LISCHEY AVE & EVANSTON AVE NB
# route                               MERIDIAN
# location             (36.190616, -86.763738)
# lat                                  36.1906
# lng                                 -86.7637
# geometry        POINT (-86.763738 36.190616)
# index_right                               42
# zip                                    37207
# po_name                            NASHVILLE
# Name: 496, dtype: object
# -------------------------
# index is 497
# values are:
#
# stop             LISCHEY AVE & EDITH AVE NB
# route                              MERIDIAN
# location            (36.201857, -86.761771)
# lat                                 36.2019
# lng                                -86.7618
# geometry       POINT (-86.761771 36.201857)
# index_right                              42
# zip                                   37207
# po_name                           NASHVILLE
# Name: 497, dtype: object
# -------------------------
# index is 501
# values are:
#
# stop                      LISCHEY AVE & EDWIN ST NB
# route                                      MERIDIAN
# location                    (36.204161, -86.761283)
# lat                                         36.2042
# lng                                        -86.7613
# geometry       POINT (-86.76128299999999 36.204161)
# index_right                                      42
# zip                                           37207
# po_name                                   NASHVILLE
# Name: 501, dtype: object
# -------------------------
# index is 512
# values are:
#
# stop             DICKERSON PIKE & OLD TRINITY LN SB
# route                                 HICKORY HILLS
# location                    (36.206868, -86.768268)
# lat                                         36.2069
# lng                                        -86.7683
# geometry       POINT (-86.76826800000001 36.206868)
# index_right                                      42
# zip                                           37207
# po_name                                   NASHVILLE
# Name: 512, dtype: object
# -------------------------
# index is 518
# values are:
#
# stop                       ROWAN DR & CARVATH DR WB
# route                                  WHITES CREEK
# location                    (36.220705, -86.811294)
# lat                                         36.2207
# lng                                        -86.8113
# geometry       POINT (-86.81129399999999 36.220705)
# index_right                                      42
# zip                                           37207
# po_name                                   NASHVILLE
# Name: 518, dtype: object
# -------------------------
# index is 536
# values are:
#
# stop           MERIDIAN ST & TREUTLAN ST SB
# route                              MERIDIAN
# location             (36.18018, -86.769153)
# lat                                 36.1802
# lng                                -86.7692
# geometry        POINT (-86.769153 36.18018)
# index_right                              42
# zip                                   37207
# po_name                           NASHVILLE
# Name: 536, dtype: object
# -------------------------
# index is 549
# values are:
#
# stop                      JONES AVE & DELLWAY DR SB
# route                                      McFERRIN
# location                    (36.212017, -86.756818)
# lat                                          36.212
# lng                                        -86.7568
# geometry       POINT (-86.75681800000001 36.212017)
# index_right                                      42
# zip                                           37207
# po_name                                   NASHVILLE
# Name: 549, dtype: object
# -------------------------
# index is 560
# values are:
#
# stop                           CHICKASAW AVE & JONES AVE WB
# route                                              McFERRIN
# location                            (36.201098, -86.758248)
# lat                                                 36.2011
# lng                                                -86.7582
# geometry       POINT (-86.75824799999999 36.20109799999999)
# index_right                                              42
# zip                                                   37207
# po_name                                           NASHVILLE
# Name: 560, dtype: object
# -------------------------
# index is 574
# values are:
#
# stop             VILLAGE TRL & BRICK CHURCH PIKE WB
# route                                DICKERSON ROAD
# location                     (36.24761, -86.777996)
# lat                                         36.2476
# lng                                         -86.778
# geometry       POINT (-86.777996 36.24760999999999)
# index_right                                      42
# zip                                           37207
# po_name                                   NASHVILLE
# Name: 574, dtype: object
# -------------------------
# index is 582
# values are:
#
# stop           OLD HICKORY BLVD & GOODMORNING DR E
# route                                HICKORY HILLS
# location                   (36.277338, -86.769987)
# lat                                        36.2773
# lng                                         -86.77
# geometry              POINT (-86.769987 36.277338)
# index_right                                     42
# zip                                          37207
# po_name                                  NASHVILLE
# Name: 582, dtype: object
# -------------------------
# index is 600
# values are:
#
# stop            WHITES CREEK PIKE & DICKERSON PKSB
# route                                 WHITES CREEK
# location                    (36.18893, -86.773288)
# lat                                        36.1889
# lng                                       -86.7733
# geometry       POINT (-86.77328799999999 36.18893)
# index_right                                     42
# zip                                          37207
# po_name                                  NASHVILLE
# Name: 600, dtype: object
# -------------------------
# index is 602
# values are:
#
# stop           TRINITY HILLS PKWY & OLD MATTHEWS RD WB
# route                                    GOLDEN VALLEY
# location                        (36.211797, -86.78956)
# lat                                            36.2118
# lng                                           -86.7896
# geometry          POINT (-86.78955999999999 36.211797)
# index_right                                         42
# zip                                              37207
# po_name                                      NASHVILLE
# Name: 602, dtype: object
# -------------------------
# index is 603
# values are:
#
# stop                CHESAPEAKE DR & TRAILWAY CIR NB
# route                                DICKERSON ROAD
# location                    (36.244252, -86.767609)
# lat                                         36.2443
# lng                                        -86.7676
# geometry       POINT (-86.76760899999999 36.244252)
# index_right                                      42
# zip                                           37207
# po_name                                   NASHVILLE
# Name: 603, dtype: object
# -------------------------
# index is 612
# values are:
#
# stop           DICKERSON PIKE & W TRINITY LN SB
# route                            DICKERSON ROAD
# location                (36.204144, -86.769144)
# lat                                     36.2041
# lng                                    -86.7691
# geometry           POINT (-86.769144 36.204144)
# index_right                                  42
# zip                                       37207
# po_name                               NASHVILLE
# Name: 612, dtype: object
# -------------------------
# index is 613
# values are:
#
# stop                   LISCHEY AVE & MARSHALL ST NB
# route                                      MERIDIAN
# location                    (36.201065, -86.761941)
# lat                                         36.2011
# lng                                        -86.7619
# geometry       POINT (-86.76194100000001 36.201065)
# index_right                                      42
# zip                                           37207
# po_name                                   NASHVILLE
# Name: 613, dtype: object
# -------------------------
# index is 642
# values are:
#
# stop           BAPTIST WORLD CENTER DR. & HAYNES MEADE CIR NB
# route                                            WHITES CREEK
# location                              (36.202481, -86.788702)
# lat                                                   36.2025
# lng                                                  -86.7887
# geometry                         POINT (-86.788702 36.202481)
# index_right                                                42
# zip                                                     37207
# po_name                                             NASHVILLE
# Name: 642, dtype: object
# -------------------------
# index is 649
# values are:
#
# stop                 SILAS DR & OLD MATTHEWS RD SB
# route                                GOLDEN VALLEY
# location                    (36.21652, -86.789628)
# lat                                        36.2165
# lng                                       -86.7896
# geometry       POINT (-86.78962800000001 36.21652)
# index_right                                     42
# zip                                          37207
# po_name                                  NASHVILLE
# Name: 649, dtype: object
# -------------------------
# index is 657
# values are:
#
# stop           DICKERSON PIKE & LUCILE ST NB
# route                         DICKERSON ROAD
# location             (36.196394, -86.771839)
# lat                                  36.1964
# lng                                 -86.7718
# geometry        POINT (-86.771839 36.196394)
# index_right                               42
# zip                                    37207
# po_name                            NASHVILLE
# Name: 657, dtype: object
# -------------------------
# index is 666
# values are:
#
# stop           HUNTERS LN & DICKERSON PIKE EB
# route                           HICKORY HILLS
# location              (36.277749, -86.752571)
# lat                                   36.2777
# lng                                  -86.7526
# geometry         POINT (-86.752571 36.277749)
# index_right                                42
# zip                                     37207
# po_name                             NASHVILLE
# Name: 666, dtype: object
# -------------------------
# index is 682
# values are:
#
# stop           WHITES CREEK PIKE & W NOCTURNE DR N
# route                                 WHITES CREEK
# location                   (36.211493, -86.797496)
# lat                                        36.2115
# lng                                       -86.7975
# geometry              POINT (-86.797496 36.211493)
# index_right                                     42
# zip                                          37207
# po_name                                  NASHVILLE
# Name: 682, dtype: object
# -------------------------
# index is 691
# values are:
#
# stop                    JONES AVE & E TRINITY LN SB
# route                                      McFERRIN
# location                    (36.205178, -86.757741)
# lat                                         36.2052
# lng                                        -86.7577
# geometry       POINT (-86.75774100000001 36.205178)
# index_right                                      42
# zip                                           37207
# po_name                                   NASHVILLE
# Name: 691, dtype: object
# -------------------------
# index is 702
# values are:
#
# stop           DICKERSON PIKE & HOMESTEAD RD SB
# route                             HICKORY HILLS
# location                (36.235483, -86.758315)
# lat                                     36.2355
# lng                                    -86.7583
# geometry           POINT (-86.758315 36.235483)
# index_right                                  42
# zip                                       37207
# po_name                               NASHVILLE
# Name: 702, dtype: object
# -------------------------
# index is 708
# values are:
#
# stop               DOVERSIDE DR & DICKERSON PIKE WB
# route                                DICKERSON ROAD
# location                    (36.244027, -86.756751)
# lat                                          36.244
# lng                                        -86.7568
# geometry       POINT (-86.75675099999999 36.244027)
# index_right                                      42
# zip                                           37207
# po_name                                   NASHVILLE
# Name: 708, dtype: object
# -------------------------
# index is 726
# values are:
#
# stop                DOVERSIDE DR & EAGLEWOOD LN EB
# route                               DICKERSON ROAD
# location                    (36.24119, -86.767902)
# lat                                        36.2412
# lng                                       -86.7679
# geometry       POINT (-86.76790200000001 36.24119)
# index_right                                     42
# zip                                          37207
# po_name                                  NASHVILLE
# Name: 726, dtype: object
# -------------------------
# index is 732
# values are:
#
# stop                    EWING DR & HILL HURST DR WB
# route                                DICKERSON ROAD
# location                    (36.230269, -86.770885)
# lat                                         36.2303
# lng                                        -86.7709
# geometry       POINT (-86.77088499999999 36.230269)
# index_right                                      42
# zip                                           37207
# po_name                                   NASHVILLE
# Name: 732, dtype: object
# -------------------------
# index is 742
# values are:
#
# stop                  FERN AVE & BRICK CHURCH PK WB
# route                                  WHITES CREEK
# location                    (36.195725, -86.776665)
# lat                                         36.1957
# lng                                        -86.7767
# geometry       POINT (-86.77666500000001 36.195725)
# index_right                                      42
# zip                                           37207
# po_name                                   NASHVILLE
# Name: 742, dtype: object
# -------------------------
# index is 759
# values are:
#
# stop                    MONTGOMERY AVE & WARD ST NB
# route                                      McFERRIN
# location                    (36.198195, -86.754837)
# lat                                         36.1982
# lng                                        -86.7548
# geometry       POINT (-86.75483699999999 36.198195)
# index_right                                      42
# zip                                           37207
# po_name                                   NASHVILLE
# Name: 759, dtype: object
# -------------------------
# index is 760
# values are:
#
# stop                    DICKERSON PIKE & ROCK ST SB
# route                                DICKERSON ROAD
# location                    (36.213706, -86.764598)
# lat                                         36.2137
# lng                                        -86.7646
# geometry       POINT (-86.76459799999999 36.213706)
# index_right                                      42
# zip                                           37207
# po_name                                   NASHVILLE
# Name: 760, dtype: object
# -------------------------
# index is 769
# values are:
#
# stop           BAPTIST WORLD CENTER DR & WILLIS ST EB
# route                                    WHITES CREEK
# location                      (36.193904, -86.778438)
# lat                                           36.1939
# lng                                          -86.7784
# geometry         POINT (-86.77843799999999 36.193904)
# index_right                                        42
# zip                                             37207
# po_name                                     NASHVILLE
# Name: 769, dtype: object
# -------------------------
# index is 774
# values are:
#
# stop           LISCHEY AVE & EVANSTON AVE SB
# route                               MERIDIAN
# location             (36.189279, -86.764073)
# lat                                  36.1893
# lng                                 -86.7641
# geometry        POINT (-86.764073 36.189279)
# index_right                               42
# zip                                    37207
# po_name                            NASHVILLE
# Name: 774, dtype: object
# -------------------------
# index is 787
# values are:
#
# stop           N DICKERSON PIKE & GRACE ST SB
# route                            WHITES CREEK
# location              (36.183867, -86.773861)
# lat                                   36.1839
# lng                                  -86.7739
# geometry         POINT (-86.773861 36.183867)
# index_right                                42
# zip                                     37207
# po_name                             NASHVILLE
# Name: 787, dtype: object
# -------------------------
# index is 788
# values are:
#
# stop                  DICKERSON PIKE & SUNSET CR SB
# route                                DICKERSON ROAD
# location                     (36.223911, -86.76099)
# lat                                         36.2239
# lng                                         -86.761
# geometry       POINT (-86.76099000000001 36.223911)
# index_right                                      42
# zip                                           37207
# po_name                                   NASHVILLE
# Name: 788, dtype: object
# -------------------------
# index is 795
# values are:
#
# stop                JONES AVE & EDWIN ST NB
# route                              McFERRIN
# location            (36.203949, -86.757812)
# lat                                 36.2039
# lng                                -86.7578
# geometry       POINT (-86.757812 36.203949)
# index_right                              42
# zip                                   37207
# po_name                           NASHVILLE
# Name: 795, dtype: object
# -------------------------
# index is 806
# values are:
#
# stop                 ROWAN DR & ROWAN CT NB
# route                          WHITES CREEK
# location            (36.221777, -86.810059)
# lat                                 36.2218
# lng                                -86.8101
# geometry       POINT (-86.810059 36.221777)
# index_right                              42
# zip                                   37207
# po_name                           NASHVILLE
# Name: 806, dtype: object
# -------------------------
# index is 811
# values are:
#
# stop           LISCHEY AVE & RICHARDSON AVE SB
# route                                 MERIDIAN
# ...
# po_name                              NASHVILLE
# Name: 2244, dtype: object
# -------------------------
# index is 2259
# values are:
#
# stop           BRICK CHURCH PIKE & CHESAPEAK DR SB
# route                               DICKERSON ROAD
# location                    (36.246128, -86.77931)
# lat                                        36.2461
# lng                                       -86.7793
# geometry       POINT (-86.77931 36.24612800000001)
# index_right                                     42
# zip                                          37207
# po_name                                  NASHVILLE
# Name: 2259, dtype: object
# -------------------------
# index is 2266
# values are:
#
# stop           BAPTIST WORLD CENTER DR & WEAKLEY AVE NB
# route                                      WHITES CREEK
# location                        (36.196511, -86.782523)
# lat                                             36.1965
# lng                                            -86.7825
# geometry                   POINT (-86.782523 36.196511)
# index_right                                          42
# zip                                               37207
# po_name                                       NASHVILLE
# Name: 2266, dtype: object
# -------------------------
# index is 2272
# values are:
#
# stop           DICKERSON PIKE & ALHAMBRA CIR NB
# route                            DICKERSON ROAD
# location                (36.219376, -86.762294)
# lat                                     36.2194
# lng                                    -86.7623
# geometry           POINT (-86.762294 36.219376)
# index_right                                  42
# zip                                       37207
# po_name                               NASHVILLE
# Name: 2272, dtype: object
# -------------------------
# index is 2279
# values are:
#
# stop                LISCHEY AVE & RICHARDSON AVE NB
# route                                      MERIDIAN
# location                    (36.193233, -86.763275)
# lat                                         36.1932
# lng                                        -86.7633
# geometry       POINT (-86.76327499999999 36.193233)
# index_right                                      42
# zip                                           37207
# po_name                                   NASHVILLE
# Name: 2279, dtype: object
# -------------------------
# index is 2290
# values are:
#
# stop           WHITES CREEK PIKE & MOORMANS ARM RD
# route                                 WHITES CREEK
# location                    (36.21818, -86.803446)
# lat                                        36.2182
# lng                                       -86.8034
# geometry       POINT (-86.80344599999999 36.21818)
# index_right                                     42
# zip                                          37207
# po_name                                  NASHVILLE
# Name: 2290, dtype: object
# -------------------------
# index is 2297
# values are:
#
# stop             VAILVIEW DR & SPEARS RD SB
# route                        DICKERSON ROAD
# location            (36.239083, -86.768621)
# lat                                 36.2391
# lng                                -86.7686
# geometry       POINT (-86.768621 36.239083)
# index_right                              42
# zip                                   37207
# po_name                           NASHVILLE
# Name: 2297, dtype: object
# -------------------------
# index is 2305
# values are:
#
# stop              ROWAN DR & BONTEMPS DR WB
# route                          WHITES CREEK
# location            (36.219615, -86.815155)
# lat                                 36.2196
# lng                                -86.8152
# geometry       POINT (-86.815155 36.219615)
# index_right                              42
# zip                                   37207
# po_name                           NASHVILLE
# Name: 2305, dtype: object
# -------------------------
# index is 2312
# values are:
#
# stop           DICKERSON PIKE & GORDON TER SB
# route                          DICKERSON ROAD
# location              (36.212823, -86.764866)
# lat                                   36.2128
# lng                                  -86.7649
# geometry         POINT (-86.764866 36.212823)
# index_right                                42
# zip                                     37207
# po_name                             NASHVILLE
# Name: 2312, dtype: object
# -------------------------
# index is 2330
# values are:
#
# stop                       JONES AVE & JONES CIR NB
# route                                      McFERRIN
# location                    (36.208884, -86.757078)
# lat                                         36.2089
# lng                                        -86.7571
# geometry       POINT (-86.75707800000001 36.208884)
# index_right                                      42
# zip                                           37207
# po_name                                   NASHVILLE
# Name: 2330, dtype: object
# -------------------------
# index is 2331
# values are:
#
# stop                      ROWAN DR & BONTEMPS DR EB
# route                                  WHITES CREEK
# location                    (36.219552, -86.815121)
# lat                                         36.2196
# lng                                        -86.8151
# geometry       POINT (-86.81512099999999 36.219552)
# index_right                                      42
# zip                                           37207
# po_name                                   NASHVILLE
# Name: 2331, dtype: object
# -------------------------
# index is 2332
# values are:
#
# stop           DICKERSON PIKE & DUE WEST AVE NB
# route                             HICKORY HILLS
# location                (36.255893, -86.757847)
# lat                                     36.2559
# lng                                    -86.7578
# geometry           POINT (-86.757847 36.255893)
# index_right                                  42
# zip                                       37207
# po_name                               NASHVILLE
# Name: 2332, dtype: object
# -------------------------
# index is 2335
# values are:
#
# stop               DICKERSON PIKE & E TRINITY LN NB
# route                                DICKERSON ROAD
# location                    (36.203912, -86.768965)
# lat                                         36.2039
# lng                                         -86.769
# geometry       POINT (-86.76896500000001 36.203912)
# index_right                                      42
# zip                                           37207
# po_name                                   NASHVILLE
# Name: 2335, dtype: object
# -------------------------
# index is 2349
# values are:
#
# stop           WHITES CREEK PIKE & TONEY RD WB
# route                             WHITES CREEK
# location               (36.208556, -86.793926)
# lat                                    36.2086
# lng                                   -86.7939
# geometry          POINT (-86.793926 36.208556)
# index_right                                 42
# zip                                      37207
# po_name                              NASHVILLE
# Name: 2349, dtype: object
# -------------------------
# index is 2361
# values are:
#
# stop           WHITES CREEK PIKE & TONEY RD SB
# route                             WHITES CREEK
# location               (36.208485, -86.793982)
# lat                                    36.2085
# lng                                    -86.794
# geometry          POINT (-86.793982 36.208485)
# index_right                                 42
# zip                                      37207
# po_name                              NASHVILLE
# Name: 2361, dtype: object
# -------------------------
# index is 2366
# values are:
#
# stop           GRACE MANOR (OLD HICKORY BLVD & BRICK CHURCH P...
# route                                              HICKORY HILLS
# location                                  (36.27961, -86.780814)
# lat                                                      36.2796
# lng                                                     -86.7808
# geometry                     POINT (-86.78081400000001 36.27961)
# index_right                                                   42
# zip                                                        37207
# po_name                                                NASHVILLE
# Name: 2366, dtype: object
# -------------------------
# index is 2369
# values are:
#
# stop                EWING DR & VISTA LN EB
# route                        GOLDEN VALLEY
# location            (36.23144, -86.795793)
# lat                                36.2314
# lng                               -86.7958
# geometry       POINT (-86.795793 36.23144)
# index_right                             42
# zip                                  37207
# po_name                          NASHVILLE
# Name: 2369, dtype: object
# -------------------------
# index is 2372
# values are:
#
# stop              EDWIN ST & LISCHEY AVE EB
# route                              MERIDIAN
# location            (36.204478, -86.763848)
# lat                                 36.2045
# lng                                -86.7638
# geometry       POINT (-86.763848 36.204478)
# index_right                              42
# zip                                   37207
# po_name                           NASHVILLE
# Name: 2372, dtype: object
# -------------------------
# index is 2383
# values are:
#
# stop                         EWING DR & EWING LN EB
# route                                DICKERSON ROAD
# location                     (36.231074, -86.77692)
# lat                                         36.2311
# lng                                        -86.7769
# geometry       POINT (-86.77691999999999 36.231074)
# index_right                                      42
# zip                                           37207
# po_name                                   NASHVILLE
# Name: 2383, dtype: object
# -------------------------
# index is 2387
# values are:
#
# stop           VAILVIEW DR & BRICKDALE LN EB
# route                         DICKERSON ROAD
# location             (36.235422, -86.772989)
# lat                                  36.2354
# lng                                  -86.773
# geometry        POINT (-86.772989 36.235422)
# index_right                               42
# zip                                    37207
# po_name                            NASHVILLE
# Name: 2387, dtype: object
# -------------------------
# index is 2397
# values are:
#
# stop                     EWING DR & HILLHURST DR EB
# route                                DICKERSON ROAD
# location                    (36.230145, -86.770902)
# lat                                         36.2301
# lng                                        -86.7709
# geometry       POINT (-86.77090200000001 36.230145)
# index_right                                      42
# zip                                           37207
# po_name                                   NASHVILLE
# Name: 2397, dtype: object
# -------------------------
# index is 2402
# values are:
#
# stop           MOOREWOOD DR & CRISLYNNDALE DR NB
# route                             DICKERSON ROAD
# location                 (36.236922, -86.773349)
# lat                                      36.2369
# lng                                     -86.7733
# geometry            POINT (-86.773349 36.236922)
# index_right                                   42
# zip                                        37207
# po_name                                NASHVILLE
# Name: 2402, dtype: object
# -------------------------
# index is 2414
# values are:
#
# stop             N DICKERSON PIKE & CLEVELAND ST SB
# route                                  WHITES CREEK
# location                    (36.187966, -86.773355)
# lat                                          36.188
# lng                                        -86.7734
# geometry       POINT (-86.77335500000001 36.187966)
# index_right                                      42
# zip                                           37207
# po_name                                   NASHVILLE
# Name: 2414, dtype: object
# -------------------------
# index is 2420
# values are:
#
# stop                DOUGLAS AVE & MONTGOMERY AVE WB
# route                                      McFERRIN
# location                    (36.193606, -86.755793)
# lat                                         36.1936
# lng                                        -86.7558
# geometry       POINT (-86.75579300000001 36.193606)
# index_right                                      42
# zip                                           37207
# po_name                                   NASHVILLE
# Name: 2420, dtype: object
# -------------------------
# index is 2426
# values are:
#
# stop                   JONES AVE & CHEROKEE AVE SB
# route                                     McFERRIN
# location                    (36.20223, -86.758198)
# lat                                        36.2022
# lng                                       -86.7582
# geometry       POINT (-86.75819799999999 36.20223)
# index_right                                     42
# zip                                          37207
# po_name                                  NASHVILLE
# Name: 2426, dtype: object
# -------------------------
# index is 2429
# values are:
#
# stop              MONTGOMERY AVE & CHICKASAW AVE NB
# route                                      McFERRIN
# location                    (36.200213, -86.754253)
# lat                                         36.2002
# lng                                        -86.7543
# geometry       POINT (-86.75425300000001 36.200213)
# index_right                                      42
# zip                                           37207
# po_name                                   NASHVILLE
# Name: 2429, dtype: object
# -------------------------
# index is 2432
# values are:
#
# stop            BRICK CHURCH PIKE & RICHMOND HILL D
# route                                DICKERSON ROAD
# location                    (36.235825, -86.781118)
# lat                                         36.2358
# lng                                        -86.7811
# geometry       POINT (-86.78111800000001 36.235825)
# index_right                                      42
# zip                                           37207
# po_name                                   NASHVILLE
# Name: 2432, dtype: object
# -------------------------
# index is 2450
# values are:
#
# stop               REVELS DR & PAIGE CIR WB
# route                          WHITES CREEK
# location            (36.221251, -86.806119)
# lat                                 36.2213
# lng                                -86.8061
# geometry       POINT (-86.806119 36.221251)
# index_right                              42
# zip                                   37207
# po_name                           NASHVILLE
# Name: 2450, dtype: object
# -------------------------
# index is 2476
# values are:
#
# stop           DICKERSON PIKE & GATEWOOD AVE SB
# route                            DICKERSON ROAD
# location                (36.200189, -86.770043)
# lat                                     36.2002
# lng                                      -86.77
# geometry           POINT (-86.770043 36.200189)
# index_right                                  42
# zip                                       37207
# po_name                               NASHVILLE
# Name: 2476, dtype: object
# -------------------------
# index is 2484
# values are:
#
# stop                    CREEKWOOD & SKYLINE APTS NB
# route                                DICKERSON ROAD
# location                    (36.232628, -86.769705)
# lat                                         36.2326
# lng                                        -86.7697
# geometry       POINT (-86.769705 36.23262800000001)
# index_right                                      42
# zip                                           37207
# po_name                                   NASHVILLE
# Name: 2484, dtype: object
# -------------------------
# index is 2508
# values are:
#
# stop           DICKERSON PIKE & RICHARDSON AVE NB
# route                              DICKERSON ROAD
# location                  (36.191582, -86.772693)
# lat                                       36.1916
# lng                                      -86.7727
# geometry             POINT (-86.772693 36.191582)
# index_right                                    42
# zip                                         37207
# po_name                                 NASHVILLE
# Name: 2508, dtype: object
# -------------------------

# %% [markdown]
# #### The map_37207 has already been created.
# - add the zipcode area outline (polygon_37207)
# - iterate through the stops_in_37207 to
#     - create location from each lat and lng
#     - create a popup from the stop column
#     - build a marker from each location and popup
#     - add the marker to  `map_37207`
# - display `map_37207`

# %%
#draw our zip code area: 37207
map_37207 = folium.Map(location =  area_center, zoom_start = 12)

folium.GeoJson(polygon37207).add_to(map_37207)

#iterate through stops_in_37207 to create locations and markers 
#for each bus stop
#remember for Folium locations, lat is listed first!!

for row_index, row_values in stops_in_37207.iterrows():
    loc = [row_values['lat'], row_values['lng']]
    pop = str(row_values['route'])
    marker = folium.Marker(
        location = loc, 
        popup = pop) 
    
    marker.add_to(map_37207)
map_37207.save('../maps/map37207.html')

#display our map
map_37207
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### If you have a lot of markers, you might want to use marker clusters
# - Folium has `MarkerCluster()` and `FastMarkerCluster()`
# - Construct a `MarkerCluster()`
#     - construct a `MarkerCluster()` and `.add_to()` the map
#     - when you loop through the data and create markers add those to the marker cluster
# - Construct a `FastMarkerCluster()` by passing a list of locations

# %%
cluster_map_37207 = folium.Map(location =  area_center, zoom_start = 12)

#create a marker cluster
marker_cluster = MarkerCluster().add_to(cluster_map_37207)

folium.GeoJson(polygon37207).add_to(cluster_map_37207)

# inside the loop add each markwe to the cluster
for row_index, row_values in stops_in_37207.iterrows():
    loc = [row_values['lat'], row_values['lng']]
    pop = str(row_values['route'])
    marker = folium.Marker(
        location = loc, 
        popup = pop) 
    
    marker.add_to(marker_cluster)

    
#save an interactive HTML map by calling .save()
cluster_map_37207.save('../maps/cluster37207.html')

cluster_map_37207
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#draw our zip code area: 37207
map_37207 = folium.Map(location =  area_center, zoom_start = 12)

folium.GeoJson(polygon37207).add_to(map_37207)

#create a list of locations and pass them to FastMarkerCluster()
locations = stops_in_37207[['lat', 'lng']].values.tolist()
map_37207.add_child(
    FastMarkerCluster(locations)
)



#display our map
map_37207
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
